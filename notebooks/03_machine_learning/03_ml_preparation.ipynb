# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    r"C:\Users\DEV\Desktop\Intelligent-Helpdesk-Analytics\data\processed\tickets_clean.csv"
)

df.head()
# Out:
#    ticket_id                       État ID de phase      Priorité  \
# 0          3                   En cours     Fulfill   Faible (P4)
# 1          4  Attente utilisateur final     Fulfill   Faible (P4)
# 2          5  Attente utilisateur final     Fulfill  Moyenne (P3)
# 3          6  Attente utilisateur final     Fulfill   Faible (P4)
# 4          7  Attente utilisateur final     Fulfill   Faible (P4)
#
#   Titre de la demande   Demandé pour Nom                 Date MAJ  \
# 0  Demande de service   Ayman El Idrissi  2026-03-18 09:18:55.978
# 1  Demande de service       Widad Tahiri  2026-03-12 10:17:36.423
# 2  Demande de service     Hassan Belkadi  2026-02-20 09:19:59.298
# 3  Demande de service  Loubna Benjelloun  2026-03-25 11:11:14.946
# 4  Demande de service       Aziz Berrada  2026-03-11 15:15:59.620
#
#         Date de résolution   Date/Heure de création  \
# 0  2026-02-13 14:20:20.000  2026-02-10 13:55:26.031
# 1                      NaN  2026-03-03 09:57:49.939
# ...

# %%
df.shape
# Out:
# (8141, 11)

# %%
df.columns.tolist()
# Out:
# ['ticket_id',
#  'État',
#  'ID de phase',
#  'Priorité',
#  'Titre de la demande',
#  'Demandé pour Nom',
#  'Date MAJ',
#  'Date de résolution',
#  'Date/Heure de création',
#  'Categorie',
#  'Temps_resolution_heures']

# %%
df_ml.isnull().sum()
# Out:
# ticket_id                     0
# État                          0
# ID de phase                   0
# Priorité                      0
# Titre de la demande           0
# Demandé pour Nom              0
# Date MAJ                      0
# Date de résolution         2321
# Date/Heure de création        0
# Categorie                     0
# Temps_resolution_heures    2321
# dtype: int64
